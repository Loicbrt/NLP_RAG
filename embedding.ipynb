# %%
from sentence_transformers import SentenceTransformer
import torch
from embedding import * 
from pathlib import Path
import os

# %%
#Install the all-MiniLM-L6-v2 for chunks embbeding
embed_model = SentenceTransformer("all-MiniLM-L6-v2")
torch.save(embed_model, "model/embed_model_all-MiniLM-L6-v2")

# %%
#Retrieve the model from disk if already downloaded
embed_model = torch.load("model/embed_model_all-MiniLM-L6-v2", weights_only=False)

# %%
#Generate the chunks data and the chunks vector database and save them
make_rag_data("data",embed_model)

# %% [markdown]
# # Partie on ou découpe les chunks à la main selon leur signification

# %% [markdown]
# Les csv on tous le même format avec ";" en délimiteur pour permettre d'utiliser "," dans les phrase
# Les fichiers textes sont séparés par paragraphe de même sens, par deux retour chariot

# %%
make_rag_data("data",embed_model,name ="varying_",method= "varying")
